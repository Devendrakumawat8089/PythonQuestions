# %%
print("Hello World !")
# Out:
# Hello World !

# %%
# 1.   WAP to Add 2 Numbers.

# %%
print(10+11)
# Out:
# 21

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print(f"The Sum Of {a} + {b} =",a+b)
# Out:
# The Sum Of 10 + 10 = 20

# %%
def add(a,b): #Parameters (a,b)
    return a + b

a =add(10,1100) # Calling Functions and pass the agruments 
print("the sum of",a)
# Out:
# the sum of 1110

# %%
b =add(11,111)
b
# Out:
# 122
