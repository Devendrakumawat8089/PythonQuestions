# %%
print("Hello World !")
# Out:
# Hello World !

# %%
# 2.   WAP to Add 3 Numbers.

# %%
print(10+20+30)
# Out:
# 60

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
c = int(input("Enter Third Number: "))
print(f"The Sum of {a} + {b} + {c} = " , a+b+c)
# Out:
# The Sum of 10 + 20 + 30 =  60

# %%
def addThreeNumbers(a,b,c):
    return a+b+c

a = addThreeNumbers(10,20,30)
print(a)
# Out:
# 60

# %%
b= addThreeNumbers(100,200,300)
b
# Out:
# 600
